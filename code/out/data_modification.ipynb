# %% [markdown]
# # Iterative labelling
# I initially labelled GTM requests based on the presence of the string `/g/collect` in request url. Running WebGraph classification pipeline has flagged other similar GTM tracking requests. I use this notebook to iteratively improve on my original labelling.

# %%
import pandas as pd

df = pd.read_csv("labelled.csv")

# %% [markdown]
# ## Only SGTM requests
# Here I discard all generic GTM requests and leave only SGTM.
#
# Results: Too few SGTM examples to train on - all SGTM requests were False Negatives

# %%
def is_google(df):
    google_domains = ['region1.google-analytics.com', 'region1.analytics.google.com', 'stats.g.doubleclick.net', 'www.google-analytics.com', 'analytics.google.com']
    values = df["name"].str.contains("|".join(google_domains), regex=True)
    return values

df_sgtm = df.copy()
# Only keep "True" label for sgtm
df_sgtm["label"] = ~ is_google(df) & df["label"]
df_sgtm[df_sgtm["label"]]
# Out:
#         Unnamed: 0      visit_id                     top_level_url  \
# 6121           128  6.586055e+13     https://www.procore.com/en-gb
# 14201           48  1.511883e+14              https://www.asu.edu/
# 14307           66  1.532234e+14       https://www.invisalign.com/
# 16006          116  1.729025e+14          https://www.hubspot.com/
# 18782          136  1.899881e+14                https://asana.com/
# ...            ...           ...                               ...
# 809165          85  8.792294e+15      https://www.centurylink.com/
# 817009         163  8.864015e+15         https://www.livesport.cz/
# 817516         128  8.865186e+15            https://www.mobile.de/
# 821417         106  8.921257e+15  https://www.topuniversities.com/
# 824238          46  8.944057e+15              https://beget.com/ru
#
#                                                      name  braveblock_label  \
# 6121    https://sgtm.procore.com/g/collect?v=2&tid=G-P...             False
# 14201   https://sstm.asu.edu/g/collect?v=2&tid=G-TEHJR...             False
# 14307   https://collect.invisalign.com/g/collect?v=2&t...             False
# 16006   https://sgtm-amer.hubspot.com/g/collect?v=2&ti...             False
# 18782   https://t-antenna.asana.com/g/collect?v=2&tid=...             False
# ...                                                   ...               ...
# 809165  https://ssgtm.centurylink.com/g/collect?v=2&ti...             False
# 817009  https://sgtm.livesport.cz/g/collect?v=2&tid=G-...             False
# 817516  https://tagging.mobile.de/g/collect?v=2&tid=G-...             False
# 821417  https://ssgtm.topuniversities.com/g/collect?v=...             False
# 824238  https://sgtm.beget.com/g/collect?v=2&tid=G-PZJ...             False
#
#         label
# 6121     True
# 14201    True
# 14307    True
# 16006    True
# 18782    True
# ...       ...
# 809165   True
# 817009   True
# 817516   True
# 821417   True
# 824238   True
#
# [203 rows x 6 columns]

# %%
df_sgtm.to_csv("labelled-sgtm.csv")
del df_sgtm

# %% [markdown]
# ## Iterative labelling
# ### Iteration 1
# Add positive labels to `/j/collect`

# %%
df_iter1 = df.copy()

df_iter1["label"] = df["label"] | df["name"].str.contains("/j/collect")
df_iter1.to_csv("labelled-iter1.csv")
df_iter1[df_iter1["name"].str.contains("/j/collect")]
# Out:
#         Unnamed: 0      visit_id               top_level_url  \
# 227             12  1.855331e+12    https://www.hdtube.porn/
# 338             29  4.494398e+12       https://www.mass.gov/
# 709            158  9.195395e+12       https://nyahentai.re/
# 2295            72  3.713770e+13   https://javtiful.com/main
# 3642           157  5.105575e+13   https://corp.world.co.jp/
# ...            ...           ...                         ...
# 826907          56  8.961515e+15  https://www.rackspace.com/
# 826940          96  8.961515e+15  https://www.rackspace.com/
# 829975          13  8.996962e+15       http://livedns.co.uk/
# 830095          39  9.000427e+15      https://kubernetes.io/
# 830519         121  9.002828e+15   https://www.netangels.ru/
#
#                                                      name  braveblock_label  \
# 227     https://www.google-analytics.com/j/collect?v=1...              True
# 338     https://www.google-analytics.com/j/collect?v=1...              True
# 709     https://www.google-analytics.com/j/collect?v=1...              True
# 2295    https://www.google-analytics.com/j/collect?v=1...              True
# 3642    https://www.google-analytics.com/j/collect?v=1...              True
# ...                                                   ...               ...
# 826907  https://www.google-analytics.com/j/collect?v=1...              True
# 826940  https://www.google-analytics.com/j/collect?v=1...              True
# 829975  https://www.google-analytics.com/j/collect?v=1...              True
# 830095  https://www.google-analytics.com/j/collect?v=1...              True
# 830519  https://www.google-analytics.com/j/collect?v=1...              True
#
#         label
# 227      True
# 338      True
# 709      True
# 2295     True
# 3642     True
# ...       ...
# 826907   True
# 826940   True
# 829975   True
# 830095   True
# 830519   True
#
# [1663 rows x 6 columns]
